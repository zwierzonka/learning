# %%
import pandas as pd
import numpy as np

from keras.layers import BatchNormalization, Dropout, Embedding, Dense, InputLayer, Flatten, Concatenate, concatenate
from keras.models import Model, Sequential
from keras.optimizers import SGD, RMSprop, Adam
from keras import backend as K
from keras.utils import to_categorical
from keras.callbacks import BaseLogger

from sklearn.model_selection import train_test_split
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.metrics import roc_auc_score
PATH='data/home-credit-risk/'

# %% [markdown]
# ### Data Preparation

# %%
app_test_df = pd.read_csv(f'{PATH}application_test.csv')
app_train_df = pd.read_csv(f'{PATH}application_train.csv')

# %%
max_cardinality = 100
train_data = app_train_df.copy()
test_data = app_test_df.copy()
cat_vars = [col for col in train_data if not 'float' in train_data[col].dtype.name and train_data[col].nunique() < 100]
cat_vars.remove('TARGET')
cont_vars = np.setdiff1d(train_data.columns.values,cat_vars+['TARGET', 'SK_ID_CURR'])

# %%
for v in cat_vars:
    test_data[v] = test_data[v].astype('str')
    train_data[v] = train_data[v].astype('str')
for v in cont_vars:
    test_data[v] = test_data[v].fillna(0).astype(np.float64)
    train_data[v] = train_data[v].fillna(0).astype(np.float64)

# %%
all_data = pd.concat([train_data,test_data],ignore_index=True, axis=0)

cat_mappers = [(c, LabelEncoder()) for c in cat_vars]
cont_mappers = [([c], StandardScaler()) for c in cont_vars]
cat_df_mapper = DataFrameMapper(cat_mappers)
cont_df_mapper = DataFrameMapper(cont_mappers)
cat_df_mapper_fit = cat_df_mapper.fit(all_data)
cont_df_mapper_fit = cont_df_mapper.fit(train_data)

# %%
cat_train_data = cat_df_mapper_fit.transform(train_data)
cont_train_data = cont_df_mapper_fit.transform(train_data)
cat_test_data = cat_df_mapper_fit.transform(test_data)
cont_test_data = cont_df_mapper_fit.transform(test_data)

# %%
all_train_data = np.concatenate([cat_train_data, cont_train_data], axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(all_train_data, train_data['TARGET'], test_size=0.27,
                                                    random_state=123)
no_cat_vars = len(cat_vars)
X_train_struct = np.split(X_train[:,:no_cat_vars], no_cat_vars, axis=1) + [X_train[:,no_cat_vars:]]
X_valid_struct = np.split(X_valid[:,:no_cat_vars], no_cat_vars, axis=1) + [X_valid[:,no_cat_vars:]]

# %%
X_test_struct = np.split(cat_test_data, no_cat_vars, axis=1) + [cont_test_data]

# %% [markdown]
# ### Build Model

# %%
## Negative loglikelihood loss function
def nll1(y_true, y_pred):
    """ Negative log likelihood. """

    # keras.losses.binary_crossentropy give the mean
    # over the last axis. we require the sum
    return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)

# %%
from typing import List, Tuple, Optional

## TODO: Weights Initialization
class MixedStructuredClassifier:
    max_emb_size = 50
    
    def get_model(
        self,
        categories_sizes: List[Tuple[str, int]],
        continious_size: int,
        output_size: int,
        linear_layers: List[int],
        linear_layers_dropout: List[int],
        embedding_dropout: int = 0
    ):
        if len(linear_layers_dropout) != len(linear_layers):
            raise Exception("Size of linear_layers_dropout and linear_layers should be equal")
            
        ## Handling Input
        embeddings = [self._get_embedding_layer(name, cat_sz, embedding_dropout) for name, cat_sz in categories_sizes]
        cont_input = InputLayer(input_shape=(continious_size,), dtype=np.float32, name='cont_input')
        
        input_layers = embeddings + [cont_input]
        input_layers_inputs = [layer.input for layer in input_layers]
        input_layers_outputs = [layer.output for layer in input_layers]
        out = concatenate(input_layers_outputs)
    
        ## Adding Dense Layers
        for i, layer_size in enumerate(linear_layers):
            out = Dense(layer_size, activation='relu', name=f'dense_layer_{i}')(out)
            out = BatchNormalization(name=f'bn_layer_{i}')(out)
            out = Dropout(linear_layers[i], name=f'dropout_layer_{i}')(out)
            
        ## Preparing output - here asume one class classification
        out = Dense(output_size, activation='softmax')(out)
        return Model(input_layers_inputs, out)
            
        
    
    def _get_embedding_layer(self, name, size, dropout):
        emb_size = min(self.max_emb_size, size)
        layers = [
            InputLayer(input_shape=(1,), dtype='int64', name=f'{name}_input'),
            Embedding(size, emb_size, input_length=1, name=f'{name}_emb'),
            Flatten(name=f'{name}_flt')
        ]
        if bool(dropout):
            layers.append(Dropout(dropout, name=f'{name}_dropout'))
        return Sequential(layers)

# %%
cat_sizes = [(name, len(le.classes_)) for name, le in cat_df_mapper_fit.features]
classifier = MixedStructuredClassifier().get_model(
    categories_sizes=cat_sizes,
    continious_size=len(cont_vars),
    output_size=2,
    linear_layers=[100, 50, 25],
    linear_layers_dropout=[0.01, 0.1, 0.2],
    embedding_dropout=0.001
)

# %%
classifier.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# NAME_CONTRACT_TYPE_input (Input (None, 1)            0
# __________________________________________________________________________________________________
# CODE_GENDER_input (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_OWN_CAR_input (InputLayer) (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_OWN_REALTY_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# CNT_CHILDREN_input (InputLayer) (None, 1)            0
# __________________________________________________________________________________________________
# NAME_TYPE_SUITE_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# NAME_INCOME_TYPE_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# NAME_EDUCATION_TYPE_input (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# NAME_FAMILY_STATUS_input (Input (None, 1)            0
# __________________________________________________________________________________________________
# NAME_HOUSING_TYPE_input (InputL (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_MOBIL_input (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_EMP_PHONE_input (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_WORK_PHONE_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_CONT_MOBILE_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_PHONE_input (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_EMAIL_input (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# OCCUPATION_TYPE_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_input (Inp (None, 1)            0
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_W_CITY_inp (None, 1)            0
# __________________________________________________________________________________________________
# WEEKDAY_APPR_PROCESS_START_inpu (None, 1)            0
# __________________________________________________________________________________________________
# HOUR_APPR_PROCESS_START_input ( (None, 1)            0
# __________________________________________________________________________________________________
# REG_REGION_NOT_LIVE_REGION_inpu (None, 1)            0
# __________________________________________________________________________________________________
# REG_REGION_NOT_WORK_REGION_inpu (None, 1)            0
# __________________________________________________________________________________________________
# LIVE_REGION_NOT_WORK_REGION_inp (None, 1)            0
# __________________________________________________________________________________________________
# REG_CITY_NOT_LIVE_CITY_input (I (None, 1)            0
# __________________________________________________________________________________________________
# REG_CITY_NOT_WORK_CITY_input (I (None, 1)            0
# __________________________________________________________________________________________________
# LIVE_CITY_NOT_WORK_CITY_input ( (None, 1)            0
# __________________________________________________________________________________________________
# ORGANIZATION_TYPE_input (InputL (None, 1)            0
# __________________________________________________________________________________________________
# FONDKAPREMONT_MODE_input (Input (None, 1)            0
# __________________________________________________________________________________________________
# HOUSETYPE_MODE_input (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# WALLSMATERIAL_MODE_input (Input (None, 1)            0
# __________________________________________________________________________________________________
# EMERGENCYSTATE_MODE_input (Inpu (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_2_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_3_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_4_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_5_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_6_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_7_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_8_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_9_input (InputLay (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_10_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_11_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_12_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_13_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_14_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_15_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_16_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_17_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_18_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_19_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_20_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_21_input (InputLa (None, 1)            0
# __________________________________________________________________________________________________
# NAME_CONTRACT_TYPE_emb (Embeddi (None, 1, 2)         4           NAME_CONTRACT_TYPE_input[0][0]
# __________________________________________________________________________________________________
# CODE_GENDER_emb (Embedding)     (None, 1, 3)         9           CODE_GENDER_input[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_CAR_emb (Embedding)    (None, 1, 2)         4           FLAG_OWN_CAR_input[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_REALTY_emb (Embedding) (None, 1, 2)         4           FLAG_OWN_REALTY_input[0][0]
# __________________________________________________________________________________________________
# CNT_CHILDREN_emb (Embedding)    (None, 1, 16)        256         CNT_CHILDREN_input[0][0]
# __________________________________________________________________________________________________
# NAME_TYPE_SUITE_emb (Embedding) (None, 1, 8)         64          NAME_TYPE_SUITE_input[0][0]
# __________________________________________________________________________________________________
# NAME_INCOME_TYPE_emb (Embedding (None, 1, 8)         64          NAME_INCOME_TYPE_input[0][0]
# __________________________________________________________________________________________________
# NAME_EDUCATION_TYPE_emb (Embedd (None, 1, 5)         25          NAME_EDUCATION_TYPE_input[0][0]
# __________________________________________________________________________________________________
# NAME_FAMILY_STATUS_emb (Embeddi (None, 1, 6)         36          NAME_FAMILY_STATUS_input[0][0]
# __________________________________________________________________________________________________
# NAME_HOUSING_TYPE_emb (Embeddin (None, 1, 6)         36          NAME_HOUSING_TYPE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_MOBIL_emb (Embedding)      (None, 1, 2)         4           FLAG_MOBIL_input[0][0]
# __________________________________________________________________________________________________
# FLAG_EMP_PHONE_emb (Embedding)  (None, 1, 2)         4           FLAG_EMP_PHONE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_WORK_PHONE_emb (Embedding) (None, 1, 2)         4           FLAG_WORK_PHONE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_CONT_MOBILE_emb (Embedding (None, 1, 2)         4           FLAG_CONT_MOBILE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_PHONE_emb (Embedding)      (None, 1, 2)         4           FLAG_PHONE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_EMAIL_emb (Embedding)      (None, 1, 2)         4           FLAG_EMAIL_input[0][0]
# __________________________________________________________________________________________________
# OCCUPATION_TYPE_emb (Embedding) (None, 1, 19)        361         OCCUPATION_TYPE_input[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_emb (Embed (None, 1, 3)         9           REGION_RATING_CLIENT_input[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_W_CITY_emb (None, 1, 4)         16          REGION_RATING_CLIENT_W_CITY_input
# __________________________________________________________________________________________________
# WEEKDAY_APPR_PROCESS_START_emb  (None, 1, 7)         49          WEEKDAY_APPR_PROCESS_START_input[
# __________________________________________________________________________________________________
# HOUR_APPR_PROCESS_START_emb (Em (None, 1, 24)        576         HOUR_APPR_PROCESS_START_input[0][
# __________________________________________________________________________________________________
# REG_REGION_NOT_LIVE_REGION_emb  (None, 1, 2)         4           REG_REGION_NOT_LIVE_REGION_input[
# __________________________________________________________________________________________________
# REG_REGION_NOT_WORK_REGION_emb  (None, 1, 2)         4           REG_REGION_NOT_WORK_REGION_input[
# __________________________________________________________________________________________________
# LIVE_REGION_NOT_WORK_REGION_emb (None, 1, 2)         4           LIVE_REGION_NOT_WORK_REGION_input
# __________________________________________________________________________________________________
# REG_CITY_NOT_LIVE_CITY_emb (Emb (None, 1, 2)         4           REG_CITY_NOT_LIVE_CITY_input[0][0
# __________________________________________________________________________________________________
# REG_CITY_NOT_WORK_CITY_emb (Emb (None, 1, 2)         4           REG_CITY_NOT_WORK_CITY_input[0][0
# __________________________________________________________________________________________________
# LIVE_CITY_NOT_WORK_CITY_emb (Em (None, 1, 2)         4           LIVE_CITY_NOT_WORK_CITY_input[0][
# __________________________________________________________________________________________________
# ORGANIZATION_TYPE_emb (Embeddin (None, 1, 50)        2900        ORGANIZATION_TYPE_input[0][0]
# __________________________________________________________________________________________________
# FONDKAPREMONT_MODE_emb (Embeddi (None, 1, 5)         25          FONDKAPREMONT_MODE_input[0][0]
# __________________________________________________________________________________________________
# HOUSETYPE_MODE_emb (Embedding)  (None, 1, 4)         16          HOUSETYPE_MODE_input[0][0]
# __________________________________________________________________________________________________
# WALLSMATERIAL_MODE_emb (Embeddi (None, 1, 8)         64          WALLSMATERIAL_MODE_input[0][0]
# __________________________________________________________________________________________________
# EMERGENCYSTATE_MODE_emb (Embedd (None, 1, 3)         9           EMERGENCYSTATE_MODE_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_2_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_2_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_3_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_3_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_4_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_4_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_5_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_5_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_6_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_6_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_7_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_7_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_8_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_8_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_9_emb (Embedding) (None, 1, 2)         4           FLAG_DOCUMENT_9_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_10_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_10_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_11_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_11_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_12_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_12_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_13_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_13_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_14_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_14_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_15_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_15_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_16_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_16_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_17_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_17_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_18_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_18_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_19_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_19_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_20_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_20_input[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_21_emb (Embedding (None, 1, 2)         4           FLAG_DOCUMENT_21_input[0][0]
# __________________________________________________________________________________________________
# NAME_CONTRACT_TYPE_flt (Flatten (None, 2)            0           NAME_CONTRACT_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# CODE_GENDER_flt (Flatten)       (None, 3)            0           CODE_GENDER_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_CAR_flt (Flatten)      (None, 2)            0           FLAG_OWN_CAR_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_REALTY_flt (Flatten)   (None, 2)            0           FLAG_OWN_REALTY_emb[0][0]
# __________________________________________________________________________________________________
# CNT_CHILDREN_flt (Flatten)      (None, 16)           0           CNT_CHILDREN_emb[0][0]
# __________________________________________________________________________________________________
# NAME_TYPE_SUITE_flt (Flatten)   (None, 8)            0           NAME_TYPE_SUITE_emb[0][0]
# __________________________________________________________________________________________________
# NAME_INCOME_TYPE_flt (Flatten)  (None, 8)            0           NAME_INCOME_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# NAME_EDUCATION_TYPE_flt (Flatte (None, 5)            0           NAME_EDUCATION_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# NAME_FAMILY_STATUS_flt (Flatten (None, 6)            0           NAME_FAMILY_STATUS_emb[0][0]
# __________________________________________________________________________________________________
# NAME_HOUSING_TYPE_flt (Flatten) (None, 6)            0           NAME_HOUSING_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_MOBIL_flt (Flatten)        (None, 2)            0           FLAG_MOBIL_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_EMP_PHONE_flt (Flatten)    (None, 2)            0           FLAG_EMP_PHONE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_WORK_PHONE_flt (Flatten)   (None, 2)            0           FLAG_WORK_PHONE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_CONT_MOBILE_flt (Flatten)  (None, 2)            0           FLAG_CONT_MOBILE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_PHONE_flt (Flatten)        (None, 2)            0           FLAG_PHONE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_EMAIL_flt (Flatten)        (None, 2)            0           FLAG_EMAIL_emb[0][0]
# __________________________________________________________________________________________________
# OCCUPATION_TYPE_flt (Flatten)   (None, 19)           0           OCCUPATION_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_flt (Flatt (None, 3)            0           REGION_RATING_CLIENT_emb[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_W_CITY_flt (None, 4)            0           REGION_RATING_CLIENT_W_CITY_emb[0
# __________________________________________________________________________________________________
# WEEKDAY_APPR_PROCESS_START_flt  (None, 7)            0           WEEKDAY_APPR_PROCESS_START_emb[0]
# __________________________________________________________________________________________________
# HOUR_APPR_PROCESS_START_flt (Fl (None, 24)           0           HOUR_APPR_PROCESS_START_emb[0][0]
# __________________________________________________________________________________________________
# REG_REGION_NOT_LIVE_REGION_flt  (None, 2)            0           REG_REGION_NOT_LIVE_REGION_emb[0]
# __________________________________________________________________________________________________
# REG_REGION_NOT_WORK_REGION_flt  (None, 2)            0           REG_REGION_NOT_WORK_REGION_emb[0]
# __________________________________________________________________________________________________
# LIVE_REGION_NOT_WORK_REGION_flt (None, 2)            0           LIVE_REGION_NOT_WORK_REGION_emb[0
# __________________________________________________________________________________________________
# REG_CITY_NOT_LIVE_CITY_flt (Fla (None, 2)            0           REG_CITY_NOT_LIVE_CITY_emb[0][0]
# __________________________________________________________________________________________________
# REG_CITY_NOT_WORK_CITY_flt (Fla (None, 2)            0           REG_CITY_NOT_WORK_CITY_emb[0][0]
# __________________________________________________________________________________________________
# LIVE_CITY_NOT_WORK_CITY_flt (Fl (None, 2)            0           LIVE_CITY_NOT_WORK_CITY_emb[0][0]
# __________________________________________________________________________________________________
# ORGANIZATION_TYPE_flt (Flatten) (None, 50)           0           ORGANIZATION_TYPE_emb[0][0]
# __________________________________________________________________________________________________
# FONDKAPREMONT_MODE_flt (Flatten (None, 5)            0           FONDKAPREMONT_MODE_emb[0][0]
# __________________________________________________________________________________________________
# HOUSETYPE_MODE_flt (Flatten)    (None, 4)            0           HOUSETYPE_MODE_emb[0][0]
# __________________________________________________________________________________________________
# WALLSMATERIAL_MODE_flt (Flatten (None, 8)            0           WALLSMATERIAL_MODE_emb[0][0]
# __________________________________________________________________________________________________
# EMERGENCYSTATE_MODE_flt (Flatte (None, 3)            0           EMERGENCYSTATE_MODE_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_2_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_2_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_3_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_3_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_4_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_4_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_5_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_5_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_6_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_6_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_7_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_7_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_8_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_8_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_9_flt (Flatten)   (None, 2)            0           FLAG_DOCUMENT_9_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_10_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_10_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_11_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_11_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_12_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_12_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_13_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_13_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_14_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_14_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_15_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_15_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_16_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_16_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_17_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_17_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_18_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_18_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_19_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_19_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_20_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_20_emb[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_21_flt (Flatten)  (None, 2)            0           FLAG_DOCUMENT_21_emb[0][0]
# __________________________________________________________________________________________________
# NAME_CONTRACT_TYPE_dropout (Dro (None, 2)            0           NAME_CONTRACT_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# CODE_GENDER_dropout (Dropout)   (None, 3)            0           CODE_GENDER_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_CAR_dropout (Dropout)  (None, 2)            0           FLAG_OWN_CAR_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_OWN_REALTY_dropout (Dropou (None, 2)            0           FLAG_OWN_REALTY_flt[0][0]
# __________________________________________________________________________________________________
# CNT_CHILDREN_dropout (Dropout)  (None, 16)           0           CNT_CHILDREN_flt[0][0]
# __________________________________________________________________________________________________
# NAME_TYPE_SUITE_dropout (Dropou (None, 8)            0           NAME_TYPE_SUITE_flt[0][0]
# __________________________________________________________________________________________________
# NAME_INCOME_TYPE_dropout (Dropo (None, 8)            0           NAME_INCOME_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# NAME_EDUCATION_TYPE_dropout (Dr (None, 5)            0           NAME_EDUCATION_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# NAME_FAMILY_STATUS_dropout (Dro (None, 6)            0           NAME_FAMILY_STATUS_flt[0][0]
# __________________________________________________________________________________________________
# NAME_HOUSING_TYPE_dropout (Drop (None, 6)            0           NAME_HOUSING_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_MOBIL_dropout (Dropout)    (None, 2)            0           FLAG_MOBIL_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_EMP_PHONE_dropout (Dropout (None, 2)            0           FLAG_EMP_PHONE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_WORK_PHONE_dropout (Dropou (None, 2)            0           FLAG_WORK_PHONE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_CONT_MOBILE_dropout (Dropo (None, 2)            0           FLAG_CONT_MOBILE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_PHONE_dropout (Dropout)    (None, 2)            0           FLAG_PHONE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_EMAIL_dropout (Dropout)    (None, 2)            0           FLAG_EMAIL_flt[0][0]
# __________________________________________________________________________________________________
# OCCUPATION_TYPE_dropout (Dropou (None, 19)           0           OCCUPATION_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_dropout (D (None, 3)            0           REGION_RATING_CLIENT_flt[0][0]
# __________________________________________________________________________________________________
# REGION_RATING_CLIENT_W_CITY_dro (None, 4)            0           REGION_RATING_CLIENT_W_CITY_flt[0
# __________________________________________________________________________________________________
# WEEKDAY_APPR_PROCESS_START_drop (None, 7)            0           WEEKDAY_APPR_PROCESS_START_flt[0]
# __________________________________________________________________________________________________
# HOUR_APPR_PROCESS_START_dropout (None, 24)           0           HOUR_APPR_PROCESS_START_flt[0][0]
# __________________________________________________________________________________________________
# REG_REGION_NOT_LIVE_REGION_drop (None, 2)            0           REG_REGION_NOT_LIVE_REGION_flt[0]
# __________________________________________________________________________________________________
# REG_REGION_NOT_WORK_REGION_drop (None, 2)            0           REG_REGION_NOT_WORK_REGION_flt[0]
# __________________________________________________________________________________________________
# LIVE_REGION_NOT_WORK_REGION_dro (None, 2)            0           LIVE_REGION_NOT_WORK_REGION_flt[0
# __________________________________________________________________________________________________
# REG_CITY_NOT_LIVE_CITY_dropout  (None, 2)            0           REG_CITY_NOT_LIVE_CITY_flt[0][0]
# __________________________________________________________________________________________________
# REG_CITY_NOT_WORK_CITY_dropout  (None, 2)            0           REG_CITY_NOT_WORK_CITY_flt[0][0]
# __________________________________________________________________________________________________
# LIVE_CITY_NOT_WORK_CITY_dropout (None, 2)            0           LIVE_CITY_NOT_WORK_CITY_flt[0][0]
# __________________________________________________________________________________________________
# ORGANIZATION_TYPE_dropout (Drop (None, 50)           0           ORGANIZATION_TYPE_flt[0][0]
# __________________________________________________________________________________________________
# FONDKAPREMONT_MODE_dropout (Dro (None, 5)            0           FONDKAPREMONT_MODE_flt[0][0]
# __________________________________________________________________________________________________
# HOUSETYPE_MODE_dropout (Dropout (None, 4)            0           HOUSETYPE_MODE_flt[0][0]
# __________________________________________________________________________________________________
# WALLSMATERIAL_MODE_dropout (Dro (None, 8)            0           WALLSMATERIAL_MODE_flt[0][0]
# __________________________________________________________________________________________________
# EMERGENCYSTATE_MODE_dropout (Dr (None, 3)            0           EMERGENCYSTATE_MODE_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_2_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_2_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_3_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_3_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_4_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_4_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_5_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_5_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_6_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_6_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_7_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_7_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_8_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_8_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_9_dropout (Dropou (None, 2)            0           FLAG_DOCUMENT_9_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_10_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_10_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_11_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_11_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_12_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_12_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_13_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_13_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_14_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_14_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_15_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_15_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_16_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_16_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_17_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_17_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_18_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_18_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_19_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_19_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_20_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_20_flt[0][0]
# __________________________________________________________________________________________________
# FLAG_DOCUMENT_21_dropout (Dropo (None, 2)            0           FLAG_DOCUMENT_21_flt[0][0]
# __________________________________________________________________________________________________
# cont_input (InputLayer)         (None, 68)           0
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 317)          0           NAME_CONTRACT_TYPE_dropout[0][0]
#                                                                  CODE_GENDER_dropout[0][0]
#                                                                  FLAG_OWN_CAR_dropout[0][0]
#                                                                  FLAG_OWN_REALTY_dropout[0][0]
#                                                                  CNT_CHILDREN_dropout[0][0]
#                                                                  NAME_TYPE_SUITE_dropout[0][0]
#                                                                  NAME_INCOME_TYPE_dropout[0][0]
#                                                                  NAME_EDUCATION_TYPE_dropout[0][0]
#                                                                  NAME_FAMILY_STATUS_dropout[0][0]
#                                                                  NAME_HOUSING_TYPE_dropout[0][0]
#                                                                  FLAG_MOBIL_dropout[0][0]
#                                                                  FLAG_EMP_PHONE_dropout[0][0]
#                                                                  FLAG_WORK_PHONE_dropout[0][0]
#                                                                  FLAG_CONT_MOBILE_dropout[0][0]
#                                                                  FLAG_PHONE_dropout[0][0]
#                                                                  FLAG_EMAIL_dropout[0][0]
#                                                                  OCCUPATION_TYPE_dropout[0][0]
#                                                                  REGION_RATING_CLIENT_dropout[0][0
#                                                                  REGION_RATING_CLIENT_W_CITY_dropo
#                                                                  WEEKDAY_APPR_PROCESS_START_dropou
#                                                                  HOUR_APPR_PROCESS_START_dropout[0
#                                                                  REG_REGION_NOT_LIVE_REGION_dropou
#                                                                  REG_REGION_NOT_WORK_REGION_dropou
#                                                                  LIVE_REGION_NOT_WORK_REGION_dropo
#                                                                  REG_CITY_NOT_LIVE_CITY_dropout[0]
#                                                                  REG_CITY_NOT_WORK_CITY_dropout[0]
#                                                                  LIVE_CITY_NOT_WORK_CITY_dropout[0
#                                                                  ORGANIZATION_TYPE_dropout[0][0]
#                                                                  FONDKAPREMONT_MODE_dropout[0][0]
#                                                                  HOUSETYPE_MODE_dropout[0][0]
#                                                                  WALLSMATERIAL_MODE_dropout[0][0]
#                                                                  EMERGENCYSTATE_MODE_dropout[0][0]
#                                                                  FLAG_DOCUMENT_2_dropout[0][0]
#                                                                  FLAG_DOCUMENT_3_dropout[0][0]
#                                                                  FLAG_DOCUMENT_4_dropout[0][0]
#                                                                  FLAG_DOCUMENT_5_dropout[0][0]
#                                                                  FLAG_DOCUMENT_6_dropout[0][0]
#                                                                  FLAG_DOCUMENT_7_dropout[0][0]
#                                                                  FLAG_DOCUMENT_8_dropout[0][0]
#                                                                  FLAG_DOCUMENT_9_dropout[0][0]
#                                                                  FLAG_DOCUMENT_10_dropout[0][0]
#                                                                  FLAG_DOCUMENT_11_dropout[0][0]
#                                                                  FLAG_DOCUMENT_12_dropout[0][0]
#                                                                  FLAG_DOCUMENT_13_dropout[0][0]
#                                                                  FLAG_DOCUMENT_14_dropout[0][0]
#                                                                  FLAG_DOCUMENT_15_dropout[0][0]
#                                                                  FLAG_DOCUMENT_16_dropout[0][0]
#                                                                  FLAG_DOCUMENT_17_dropout[0][0]
#                                                                  FLAG_DOCUMENT_18_dropout[0][0]
#                                                                  FLAG_DOCUMENT_19_dropout[0][0]
#                                                                  FLAG_DOCUMENT_20_dropout[0][0]
#                                                                  FLAG_DOCUMENT_21_dropout[0][0]
#                                                                  cont_input[0][0]
# __________________________________________________________________________________________________
# dense_layer_0 (Dense)           (None, 100)          31800       concatenate_28[0][0]
# __________________________________________________________________________________________________
# bn_layer_0 (BatchNormalization) (None, 100)          400         dense_layer_0[0][0]
# __________________________________________________________________________________________________
# dropout_layer_0 (Dropout)       (None, 100)          0           bn_layer_0[0][0]
# __________________________________________________________________________________________________
# dense_layer_1 (Dense)           (None, 50)           5050        dropout_layer_0[0][0]
# __________________________________________________________________________________________________
# bn_layer_1 (BatchNormalization) (None, 50)           200         dense_layer_1[0][0]
# __________________________________________________________________________________________________
# dropout_layer_1 (Dropout)       (None, 50)           0           bn_layer_1[0][0]
# __________________________________________________________________________________________________
# dense_layer_2 (Dense)           (None, 25)           1275        dropout_layer_1[0][0]
# __________________________________________________________________________________________________
# bn_layer_2 (BatchNormalization) (None, 25)           100         dense_layer_2[0][0]
# __________________________________________________________________________________________________
# dropout_layer_2 (Dropout)       (None, 25)           0           bn_layer_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            52          dropout_layer_2[0][0]
# ==================================================================================================
# Total params: 43,532
# Trainable params: 43,182
# Non-trainable params: 350
# __________________________________________________________________________________________________

# %%
classifier.compile(optimizer=Adam(lr=1e-3), loss=nll1, metrics=['accuracy'])

# %%
classifier.fit(
    x=X_train_struct,
    y=to_categorical(y_train),
    batch_size=128,
    epochs=3,
    validation_data=(X_valid_struct, to_categorical(y_valid))
)
# Out:
# Train on 224483 samples, validate on 83028 samples
# Epoch 1/3
# 224483/224483 [==============================] - 70s 313us/step - loss: 0.5669 - acc: 0.9086 - val_loss: 0.5201 - val_acc: 0.9183
# Epoch 2/3
# 224483/224483 [==============================] - 57s 254us/step - loss: 0.5098 - acc: 0.9195 - val_loss: 0.5189 - val_acc: 0.9177
# Epoch 3/3
# 224483/224483 [==============================] - 57s 255us/step - loss: 0.5059 - acc: 0.9196 - val_loss: 0.5141 - val_acc: 0.9183
